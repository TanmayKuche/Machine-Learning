# %%
import pandas as pd

# %% [markdown]
# ### local file

# %%
df = pd.read_csv("placement.csv")
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %% [markdown]
# ### using url from server

# %% [markdown]
# ### Sep Parameter

# %%
df = pd.read_csv("titanic-parquet.tsv" , sep = '\t')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                               Heikkinen, Miss. Laina  female  26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                             Allen, Mr. William Henry    male  35      0
# ..                                                 ...     ...  ..    ...
# ...

# %% [markdown]
# in this also we ccan use names=['column1' , 'column2' .. ] to define the column name if not given
# df = pd.read_csv("titanic-parquet.tsv" , sep = '\t' , names=['column1' , 'column2' .. ])

# %% [markdown]
# ### index col parmeter

# %%
pd.read_csv("titanic-parquet.tsv" , sep ="\t", index_col = 'PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38
# 3                                       Heikkinen, Miss. Laina  female  26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35
# 5                                     Allen, Mr. William Henry    male  35
# ...                                                        ...     ...  ..
# ...

# %% [markdown]
# remove the index creted by pandas using index col parmetr

# %% [markdown]
# ### Header parameter

# %%
pd.read_csv("placement.csv" , header = 1)
# Out:
#      0  6.8  123.0  1
# 0    1  5.9  106.0  0
# 1    2  5.3  121.0  0
# 2    3  7.4  132.0  1
# 3    4  5.8  142.0  0
# 4    5  7.1   48.0  1
# ..  ..  ...    ... ..
# 94  95  4.3  200.0  0
# 95  96  4.4   42.0  0
# 96  97  6.7  182.0  1
# 97  98  6.3  103.0  1
# 98  99  6.2  113.0  1
#
# [99 rows x 4 columns]

# %% [markdown]
# now here the data started directly from 1st line

# %% [markdown]
# ### use_cols parameter

# %%
pd.read_csv("placement.csv" , usecols = ['cgpa' , 'iq'])
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %% [markdown]
# using only those column which we want

# %% [markdown]
# ### squeeze
# now it will become pandas series

# %%
df = pd.read_csv("placement.csv", usecols=['cgpa'])
series = df.squeeze('columns')

# %% [markdown]
# ### Skiprows/nrows Parameter

# %%
df = pd.read_csv("placement.csv" , skiprows = [0,1])

# %% [markdown]
# #### nrows gives only specified number of rows

# %%
df = pd.read_csv("placement.csv" , nrows = 100)

# %% [markdown]
# ### encoding parameter

# %%
df = pd.read_csv("placement.csv" , encoding = 'latin-1')

# %% [markdown]
# used to change encoding

# %% [markdown]
# ### Skip bad line

# %% [raw]
# df = pd.read_csv("ex.csv" , sep = ';' , encoding = 'latin-1' , error_bad_lines= False)

# %% [markdown]
# used to skip bad line like if one line contain 8 rows instead of 7

# %% [markdown]
# ### dtypes paramter

# %% [raw]
# df = pd.read_csv("ex.csv" , dtype = {'col_nm' : int})

# %% [raw]
# use to change datatype in data

# %% [markdown]
# ### Handling data

# %% [raw]
# df = pd.read_csv("ex.csv" , parse_dates = ['date'])

# %% [markdown]
# it is use treat date as date not as object so we can use filter and all

# %% [markdown]
# ### converter

# %% [raw]
# rename(name):
#     if name == 'mumbai indians':
#         return "mi"
#     else :
#         return name

# %% [raw]
# pd.read_csv("ex.csv" , converters = {'team1' : rename})

# %% [markdown]
# this is use to covert row names we can add as many column we want in dictonary

# %% [markdown]
# ### na_values parameter

# %% [raw]
# df = pd.read_csv("ex.csv" , na_values = ["/"])

# %% [markdown]
# now this '/' will be treated as NA

# %% [markdown]
# ### Loading huge data set in chunks

# %%
dfs = pd.read_csv("placement.csv" , chunksize = 50)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (50, 4)

# %% [markdown]
# it is use to divided big data in chunks
